# %% [markdown]
# # Unspervised learning project 1

# %%
from kohonen import *
from Supplementary import *
import numpy as np

# %%
name = "Stettler"
nameDigit = name2digits(name)
print(nameDigit)
# Out:
# [0 4 7 8]

# %% [markdown]
# ### import data

# %%
data = np.loadtxt("data.txt")
labels = np.loadtxt("labels.txt")

# %%
data_filtered, labels_flitered = filterData(data,labels,name)
print(np.shape(data_filtered))
#visualizeSample(data[0])
# Out:
# target digits = [0 4 7 8]
# (2000, 784)

# %%
centers = run_kohonen(data_filtered, size_k=4, sigma=3.0, eta=0.2, tmax=100000)
visualizeSample(centers, size_k=4)

# %%
average_digit = averageSample(data_filtered, labels_flitered, nameDigit)
visualizeSample(average_digit)
# Out:
# (4, 784)

# %%
digits = []
for center in centers:
    rmses = []
    for digit in average_digit:
        rmses.append(distance_btw_Sample(center,digit))
    
    digits.append(nameDigit[np.argmin(rmses)])
    
print(digits)
# Out:
# [0, 0, 0, 4, 0, 4, 0, 0, 0, 4, 4, 4, 0, 0, 4, 4, 4, 4, 0, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-344e4d34747d> in <module>()
# ----> 1 visualizeSample(centers, size_k=6)
#
# C:\Users\jb\Documents\EPFL\MA4\Reingorcement Learning\Unsupe1\Supplementary.py in visualizeSample(sample, size_k)
#      14     if size_k:
#      15         plt.figure(2.5 * int(size_k))
# ---> 16         for i, s in enumerate(sample):
#      17             plt.subplot(size_k, size_k, i)
#      18             s = np.reshape(s, (28,28))
#
# NameError: name 'samples' is not defined
